# %%
# Load the autoreload extension
# %load_ext autoreload

# Set autoreload mode to automatically reload all modules
# %autoreload 2

from model.Simulation import EnergyModel

m = EnergyModel()
m.init_sim()
m.simulate()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# initializing Building object from data\building_oib_16linie.xlsx

# %%
m.plot()
# Out:
# c:\Users\Simon Schneider\Code\games\passyBuird\model\Simulation.py:327: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown

# %%
m
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\site-packages\IPython\core\formatters.py:708, in PlainTextFormatter.__call__(self, obj)
#     701 stream = StringIO()
#     702 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     703     self.max_width, self.newline,
#     704     max_seq_length=self.max_seq_length,
#     705     singleton_pprinters=self.singleton_printers,
#     706     type_pprinters=self.type_printers,
#     707     deferred_pprinters=self.deferred_printers)
# --> 708 printer.pretty(obj)
#     709 printer.flush()
#     710 return stream.getvalue()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\IPython\lib\pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
#     409                         and callable(cls.__dict__.get('__repr__')):
# --> 410                     return _repr_pprint(obj, self, cycle)
#     412     return _default_pprint(obj, self, cycle)
#     413 finally:
#
# File c:\ProgramData\anaconda3\Lib\site-packages\IPython\lib\pretty.py:778, in _repr_pprint(obj, p, cycle)
#     776 """A pprint that just redirects to the normal repr function."""
#     777 # Find newlines and replace them with p.break_()
# --> 778 output = repr(obj)
#     779 lines = output.splitlines()
#     780 with p.group():
#
# File c:\Users\Simon Schneider\Code\games\passyBuird\model\Simulation.py:416, in EnergyModel.__repr__(self)
#     400         string = f"""
#     401 Gebäude    {self.building.file}
#     402 BGF        {self.building.bgf} m²BGF
#    (...)
#     406
#     407 """
#     408         if self.simulated:
#     409             string += f"""
#     410 Heizwärmebedarf (QH):       {self.QH.sum() / 1000:>5.1f} kWh/m²BGFa
#     411 Kühlbedarf (QC):            {-self.QC.sum() / 1000:>5.1f} kWh/m²BGFa
#     412 Strombedarf (ED):           {self.ED.sum() / 1000:>5.1f} kWh/m²BGFa
#     413 PV Eigenverbrauch (PV_use): {self.PV_use.sum() / 1000:>5.1f} kWh/m²BGFa
#     414 Netzstrom (ED_grid):        {self.ED_grid.sum() / 1000:>5.1f} kWh/m²BGFa
#     415 {"-" * (width + 20)}
# --> 416 Investkosten:               {self.investment_cost:>10.0f} €
#     417 Betriebskosten pro Jahr:   ({self.operational_cost:>10.0f} €/a)
#     418 Betriebskosten (20 Jahre):  {self.operational_cost * 20:>10.0f} €
#     419 Gesamtkosten:               {self.total_cost:>10.0f} €"""
#     420         return string
#
# AttributeError: 'EnergyModel' object has no attribute 'investment_cost'
